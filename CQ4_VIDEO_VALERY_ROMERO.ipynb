# %% [markdown]
# ##TRANSCRIPCIÓN DEL VIDEO
#
# Entonces, acabas de empezar a aprender Python y quieres desarrollar un proyecto genial después de aprender los conceptos básicos. Esta serie de videos es exactamente para ti porque en esta serie de videos vamos a desarrollar un juego con Python. Si conoces los conceptos básicos y tomaste algún curso básico, sin importar el canal o el curso, esta es la serie que estás buscando porque te dará los conceptos básicos de cómo empezar a estructurar un proyecto de Python. En esta serie, desarrollaremos un juego llamado Buscaminas, que es conocido como un juego para un solo jugador, muy divertido y desafiante. Veamos qué juego aprenderás a desarrollar en esa serie. Bien, ese será el juego que desarrollaremos a lo largo de esta serie. Ahora puedes ver que tenemos una cantidad de ventas en las que podemos hacer clic para abrirlas. El objetivo principal de Buscaminas es no hacer clic en una venta que tenga una mina detrás de la celda. Entonces, ¿qué significa eso? Significa que si fuera a abrirlo, verías que recibo un número de vuelta. Esto significa que en las celdas rodeadas De esa celda hay una mina en la que no debería hacer clic así que voy a adivinar y diga que no tiene una mente aquí y tampoco la tiene allí y puede ver que tengo toda la razón, así que haré clic con el botón derecho del mouse para marcarlo como una mina porque si hago clic con el botón izquierdo del mouse, perderé el juego , así que lo que voy a hacer ahora es
# Intenta adivinar el resto de las ubicaciones que no tienen sentido, así que voy a hacer clic allí y puedes ver que recibí algunos números, puedes ver que, por ejemplo, alrededor de la celda no tengo sentido, así que es seguro hacer clic aquí y también allí. Ahora intentemos hacer clic izquierdo en esa ubicación y puedes ver que dice que hiciste clic en una mina y perdí una partida. El objetivo principal es adivinar todas las ubicaciones que no tienes en mente y luego ganarás la partida. Así que vamos a tener que pensar mucho para desarrollar ese juego y va a ser genial lidiar con todos los desafíos que trae consigo este juego, así que antes de empezar, agradecería que hicieras clic en el botón "Me gusta" en ese video. Ayudaría a difundir el video en todo YouTube. Además, si conoces a alguien que recién esté empezando a aprender Python y quiera desarrollar un proyecto interesante, invítalo a ver mi serie también. Podría ser muy útil para esos videos que están en el nivel entre empezar y ser un experto. dicho esto comencemos [Música] Ahora, antes de comenzar a escribir este proyecto, espero que tengas Python instalado en tu computadora, así como un IDE listo para usar y que reconozca el intérprete de Python en tu computadora. Voy a usar Python 3.8, pero siempre que tengas una versión superior, entonces deberías estar bien escribiendo este proyecto. Ahora no vamos a usar demasiadas bibliotecas externas o demasiado código que dependa de la versión de Python, así que está bien si incluso usas Python 3.10 o Python 3.11, que probablemente estarán disponibles en el futuro. Está bien, así que sigamos adelante y comencemos ahora a escribir un juego de mesa, un juego en 2D, entonces podemos usar muchas bibliotecas que están disponibles en Python. En este, vamos a usar TK Inter, que es muy bueno y una gran biblioteca para practicar porque viene con muchas clases útiles que vamos a instanciar para crear nuestra ventana, así que vamos a comenzar importándolo de la siguiente manera. Diré que front kinter importa todo y eso será un gran comienzo para nosotros, así que la siguiente línea que voy a escribir aquí es crear una instancia de ventana y nosotros Probablemente quieras hacer eso porque nuestro proyecto va a estar en una ventana y voy a nombrar mi variable root y esta va a ser igual a una instancia de esa palabra clave tk y ese es solo el elemento más básico que puedes crear, esta es solo una ventana normal ahora, cuando ejecutemos esto, no va a pasar nada porque necesitamos decirle a ese tk que debe ejecutarse hasta que lo cerremos con el botón x en la esquina superior derecha, así que será diciendo root dot main loop así , así que necesitamos llamar a ese método y todo el código va a estar entre esas dos líneas así que si tuviéramos que ejecutar eso y puedes ver que tenemos la ventana más básica que es posible ahora solo una nota rápida al margen la razón por la que usé la variable root es solo una convención en tk inter proyectos por lo que será más fácil para ti buscar problemas en Stack Overflow por ejemplo si sigues esas convenciones muy bien, sigamos adelante y veamos algunos de los atributos que podemos cambiar aquí para hacer que nuestra ventana sea más agradable así que el primero va a ser obviamente cambiar el tamaño de la ventana y podemos hacerlo llamando a la función de geometría i método medio de esta raíz y esto acepta una cadena que se parece a lo siguiente peso x altura y aquí, obviamente, puede poner cualquier número que desee. Ahora, preste atención a lo que sucederá si los reemplazara con números reales como los siguientes, entonces verá la diferencia inmediatamente y si lo ejecutara, puede ver cómo cambia. Ahora también podemos prestar atención a que usa esta cadena como el título de nuestra ventana. Podemos cambiar eso llamando a un método llamado título y darle cualquier título que queramos para que podamos ir con un juego de buscaminas y volver a ejecutar nuestro programa y puede ver los cambios. Ahora no hablé de esto, pero de forma predeterminada, todas las ventanas son redimensionables y eso puede ser algo molesto cuando crea muchos elementos dentro de esta ventana, como botones o marcos, por eso probablemente busquemos evitar redimensionar esta ventana porque nos dará una vida más fácil cuando avancemos y coloquemos más elementos en esa ventana, así que la forma en que esto se puede lograr es llamando al método redimensionable de esa manera y básicamente especificando que no se nos permite redimensionar el ancho y la altura de esta ventana y eso se puede lograr básicamente pasando dos veces una para el peso y la otra para la altura. Si volviera a ejecutar nuestro programa, puede ver el efecto. Puede ver que esta maximización está deshabilitada y eso es algo que nos facilitará la vida en el futuro cuando desarrollemos este juego. Después de llegar a esa etapa, también podríamos tener curiosidad sobre cómo cambiar el color de fondo de nuestra ventana. Puede continuar y usar valores hexadecimales si sabe cómo usarlos, pero básicamente Kinder admite muchas palabras clave para especificar los colores. Ahora no queremos lidiar demasiado con el estilo, queremos centrarnos en la lógica del algoritmo de cómo escribir un juego así, así que para ese propósito lo mantendré simple, pero aún así queremos tener una ventana visualizada agradable aquí, así que iré a esa quinta línea y diré root.configure y necesitaremos configurar el color de fondo para nuestra ventana, así que necesitamos continuar y llamar a este método y Necesito pasar en bg es igual a cualquier color que queramos ahora en la descripción puedes encontrar una lista de colores disponibles usando la palabra clave colors así que en la descripción hay un enlace con una gran lista de colores disponibles solo voy a usar negro para esta ventana y eso será todo para que puedas ver el efecto inmediato de cambiar el color de fondo muy bien ahora que entendimos esto entonces sigamos adelante y veamos cómo podemos crear algunos elementos dentro de nuestra ventana ahora vamos a comenzar con el elemento más básico que puedes crear en una ventana que se llama marco ahora el marco es como un contenedor que podría contener más elementos que crearemos en el futuro ahora queremos usar esos marcos porque obviamente queremos dividir nuestra ventana en algunas secciones para que sea más fácil entender dónde queremos ubicar cada uno de nuestros botones o textos en el futuro por ejemplo podríamos dedicar esa área de nuestra ventana para un título bien así tendremos el título aquí y podríamos decidir que nos gustaría tener una barra lateral izquierda así que podríamos dedicar el área izquierda de nuestra ventana para que sea la barra lateral para mostrar la partitura por ejemplo algo así y podríamos tener otro marco aquí para poder mostrar el juego aquí, así que es una gran idea dividir la ventana en varios marcos, será útil visualizar diferentes elementos más adelante, así que lo que voy a hacer ahora es escribir aquí un comentario que diga anular la configuración de la ventana y justo antes del bucle principal del punto raíz también voy a comentar ejecutar la ventana y luego aquí está la ubicación exacta en la que comenzaremos a crear algunos marcos, así que sigamos adelante y comencemos, así que dijimos que nos gustaría tener un marco que se encuentre en la parte superior, así que nombraré esta variable marco superior y eso será igual a una clase que se llama marco y una vez que instanciaremos de esta clase de marco, entonces será responsable de instanciar un marco que decidiremos más adelante dónde nos gusta ubicarlo en nuestra ventana ahora el primer argumento que debe recibir este marco es cuál es el elemento en el que nos gusta ubicar el marco, por lo que se ubicará en la ventana, así que pasaremos en raíz y luego los separaré en varias líneas para que sea más fácil de leer y como puedes ver los paréntesis están abiertos aquí, cerrados aquí. Ahora sigamos adelante y asigné más atributos. Primero lo primero, nos gustaría darle un fondo diferente para que podamos diferenciar realmente entre el marco y la ventana porque será difícil entender dónde se encuentra el marco si mantenemos el mismo color, así que solo por razones de depuración mantengo este cambio de rojo a negro más tarde y comentaremos eso aquí y luego aquí abajo decidiré el ancho y la altura, así que diré que el ancho debe ser igual al mismo tamaño de ancho que le dimos a la ventana porque nos gustaría cubrir toda la ventana, así que este debería ser el ancho completo como la ventana y la altura debería ser probablemente um 180 así, así que es solo 720 dividido a 4 y eso tiene todo el sentido y ahora que tenemos esto, entonces necesitamos decidir dónde nos gustaría comenzar este marco, así que para hacer esto, entonces voy a seguir adelante y decir guión bajo superior marco punto lugar ahora este lugar recibirá dos argumentos que son obligatorios y Antes de continuar y pasarlos, déjenme mostrarles cómo funciona el método de lugar en la ventana aquí. Cuando usamos el método de lugar, necesita recibir el valor del píxel. Ahora sabemos que tenemos un marco que nos gustaría comenzar exactamente desde aquí y sabemos que probablemente debería cubrir esta área, ¿verdad? Pero, ¿cómo le vamos a decir que comience desde aquí? Bueno, en su lugar, necesitamos especificar el eje X y el eje Y, lo que significa que si queremos comenzar desde la parte superior izquierda, debemos darle los valores de 0.0 porque ahí es donde todo comienza en términos de píxeles. Ahora, el área completa aquí es de 1440 porque ese es el eje X y el eje Y es de 720 píxeles, por lo que la altura completa aquí es de 720. Ahora, si, por ejemplo, quisiéramos tener un botón, solo por ejemplo, no voy a hacer eso en ese momento, pero digamos que nos gustaría tener un botón que quisiéramos que comenzara aquí, así que queríamos colocarlo en el medio de nuestra página, ¿verdad? Entonces, necesitamos tomar ese valor y dividirlo por dos para que el eje X sea 720. y sabemos que nos gustaría tener en la posición superior tanto como sea posible, por lo que este debería ser el valor del eje y, que será cero, así es como funciona el método de lugar. Necesitamos especificar el valor de píxel para el eje x y el eje y. Déjame limpiar todo lo que dibujé aquí y volver a PyCharm y dar aquí los valores de x igual a cero e y igual a cero. Ahora, mira cómo se visualizará este cuadro si me detengo y vuelvo a ejecutarlo. Entonces puedes ver que este es el resultado esperado, tal como queríamos, comenzó desde aquí y tomó toda el área de peso y tomó 180 píxeles de la altura, así que eso es exactamente lo que queríamos ahora. Solo para asegurarme de que entendiste esto, voy a cambiar esto a x a 20 y adivinarás qué sucederá. Entonces, si volviéramos a ejecutarlo, obviamente, comenzará desde una posición un poco a la izquierda, puedes ver dónde se encuentra justo aquí. Comienza justo aquí. Y si saltamos la y por 20 y nos detenemos y volvemos a ejecutar esto, entonces puedes ver los resultados. Así es como funciona el método de lugar, obviamente voy a cambiar esos volver a cero y continuar desde aquí está bien, entonces ahora que entendimos eso, sigamos adelante e intentemos crea un marco más ahora esta vez quiero hacer un marco que usaremos como barra lateral izquierda donde mostraremos tal vez la puntuación o algo más que sea útil, así que voy a seguir adelante y crear una variable de marco izquierdo y eso será igual al marco así que instanciaremos uno más de esa clase y queremos este marco en la raíz y luego diremos algo como bg es igual a otro color simplemente copiaré esa línea y pegaré esto y usemos algo como azul para que podamos separar entre diferentes marcos y el ancho será um 360. Estoy usando intencionalmente el valor que es solo una cuarta parte de ese valor para que me sea más fácil entender qué porcentaje del ancho total cubrí con mis marcos ahora que especifiqué el peso voy a especificar la altura así que voy a decir que esto debe cubrir toda la altura de nuestra ventana ahora preste atención a que ya cubrimos 180 píxeles para el marco superior así que no podemos decir simplemente 780 quiero decir 720 así tenemos que seguir adelante y recordar nuestro tamaño de altura de toda la ventana y restar este número por ese número correcto, por lo que deberíamos pasar aquí 540.
# Ahora no se preocupen si creen que codificamos demasiados valores, me aseguraré de que realmente no tengamos ningún valor codificado más adelante cuando reestructuremos este proyecto en el futuro, así que ahora nos estamos enfocando en comprender cómo funciona tkinter. Ahora que entendimos eso, sigamos adelante y digamos que el marco izquierdo debe colocarse en x igual a cero, pero la y debe ser igual a 180, ¿verdad? Porque queremos comenzar justo después de donde se encuentra el marco superior y si tuviera que ejecutar nuestro programa, entonces pueden ver que tenemos el resultado perfecto, solo para realmente entender eso de nuevo, si tomáramos ese eje y y lo saltáramos por 20, entonces pueden ver que comienza justo desde aquí porque saltó 20 píxeles en el eje y, así que es por eso que quiero asegurarme de que mantenemos el valor de 180, ¿verdad? Así que ahora que hemos llegado a esa etapa, pueden notar probablemente que vamos a tener demasiados números codificados en términos de usar el peso, la altura y los píxeles etc así que eso es Es genial tener un archivo separado para todas nuestras constantes y tener al menos algunas variables almacenadas en algún lugar. Ahora no voy a hacer eso en nuestro archivo main.py porque podría ser demasiada información que necesita almacenarse en un solo archivo. Además, voy a tomar un nuevo archivo de Python y lo llamaré " configuraciones". Aquí dentro puedo usar algunas constantes que serán útiles y para mostrarles realmente esas ventanas una al lado de la otra, permítanme usar el clic derecho y la opción de dividir verticalmente para que podamos comenzar a pensar en algunos buenos candidatos para las variables que nos gustaría almacenar aquí. Por ejemplo, podemos comenzar con el tamaño del ancho de nuestra ventana. Podemos decir que el peso es igual a 1400 y podemos decir que la altura es igual a 720. Podemos volver inmediatamente a nuestro archivo principal de punto py y decir algo como importar configuraciones. Luego podríamos ir aquí y usar una cadena formateada y podríamos simplemente convertirlas en esa cadena. Podemos decir aquí "configuraciones punto espera" y podemos ir con configuraciones. La altura del punto es así y eso es un gran cambio en nuestro proyecto. Si ejecuto nuestro archivo principal, puede ver que nada ha cambiado realmente y estamos en buena posición para continuar haciendo esas manipulaciones para almacenar más variables. Si recuerda que dije en el tutorial que usé intencionalmente esos números para que pudiéramos tener un porcentaje preciso del tamaño del peso, por ejemplo, hubo una gran razón por la que usé el valor 180 en la altura de los marcos superiores porque 180 por 4 es 720, así que puedo decir que me gustaría consumir 25 de la altura total de nuestra ventana. Y esas son cosas importantes porque no tendremos demasiados valores codificados, así que lo que podemos hacer ahora es tener un archivo para algunas funciones que podrían ser útiles para calcular esas cosas. Por ejemplo, podríamos tener una función que calcule cuánto es 20 de la altura total de nuestra ventana. Entonces podemos seguir adelante y usar otro archivo de Python para eso, podemos llamarlo utilidades o utils, y podríamos tener una función que calcule el porcentaje de nuestra altura. Al principio, podríamos seguir adelante. y usar la configuración de importación para importar la configuración de nuestro proyecto y podríamos seguir adelante y usar una función, así que llamemos a esta función altura guión bajo prct solo una versión abreviada de porcentaje correcto para que podamos seguir adelante y recibir aquí la cantidad de porcentaje como parámetro, lo hacemos un poco más pequeño y luego puedo seguir adelante y dentro de eso puedo devolver el valor confiando en el argumento recibido aquí para que pueda seguir adelante y usar retorno y puedo decir configuración punto altura dividido por 100 y puedo cubrir esto con paréntesis y puedo multiplicar eso con la cantidad de porcentaje así que ahora quiero validar que he hecho un gran trabajo escribiendo esta función correcto no quiero llamar inmediatamente a mis funciones y solo intentar usarlas porque podría tener un error cuando escribo una función y eso también es una gran ventaja ubicar diferentes funciones en diferentes archivos porque le dará una gran ventaja depurando sus cosas así que por ejemplo podría ejecutar temporalmente solo el archivo utils.py y solo probar mi función podría seguir adelante e intentar llámalo y pasa el año 25 y valida que realmente recibiré de vuelta para que pueda seguir adelante y usar imprimir y ejecutar utilidades para que no esté ejecutando mi proyecto original y ahora si sigues adelante y ves el valor aquí puedes ver que realmente recibo 180 y eso es bueno, eso significa que hemos hecho un gran trabajo escribiendo esta función y ahora realmente puedo comenzar a usarla en nuestro proyecto original, es decir, en el archivo main.py para que pueda seguir adelante e importar todos los archivos de utilidades también puedo decir importar utils y puedo seguir adelante y llamar a la función de porcentaje de altura puedo usar utils.height prct y pasar 25 y nuevamente esto no tendrá ningún efecto esto significa que hemos hecho un gran trabajo solo que ahora somos más dinámicos y no codificamos valores vamos a repetirnos con el peso muy rápidamente y luego pasaremos al siguiente tema correcto, así que voy a ir aquí y voy a usar altura de profundidad, es decir, peso prct recibiremos nuevamente porcentaje y diremos devolver abre los paréntesis para que podamos tener una visión más clara de esta fórmula y podemos decir "configuraciones ancho de punto dividido en 100 multiplicado por el porcentaje" así que ahora puedo seguir adelante y hacer prácticamente lo mismo en los diferentes valores codificados aquí así que echemos un vistazo así que en el marco superior usamos toda la ventana así que tiene sentido cambiar esto solo al valor de settings.width derecha porque ya es 1440.
# vayamos a nuestro marco izquierdo así que en el marco izquierdo vemos que usamos 25 de todo el ancho así que podemos seguir adelante y usar utils dot height prct disculpen con prct voy a cambiar eso y luego pasaré 25 y también pueden ver que en la altura usamos el 75 por ciento de toda nuestra altura así que eso significa que puedo usar aquí el procedimiento utils dot height y pasar el año 75 y puedo hacer lo mismo cuando quiero ubicar mi marco izquierdo y pueden notar cómo el valor del eje y aquí es nuevamente 25 de toda la altura así que pueden decir utils.height prct y pasar aquí 25 Ahora veamos si hemos hecho un buen trabajo. Puedes ver que el resultado es perfecto. Bien, ahora que tenemos esto, déjame cambiarlos a los valores originales y continuar desde aquí para crear nuestro último marco. Dijimos que también nos gustaría tener un marco más en el centro de la página para que tengamos un marco dedicado a nuestro juego. Rápidamente crearé un marco central que será igual a un marco . Este debería estar dentro de la raíz. El fondo debería ser verde para que podamos separarlo. Necesitaré cambiar todo eso a negro en unos minutos . Luego, diré que el peso es igual a utils con prct. Esta vez, me gustaría usar el 75% de nuestro ancho total. La altura será igual a utils dot height velocity, que también será 75. Ahora, el método place recibirá los siguientes argumentos. El valor x debería ser utils dot width piacity 25, porque queremos comenzar desde aquí. La altura significa el eje y. Debería ser el mismo, ¿verdad? Así que voy a duplicar eso y cambiar esto a height plct así porque queremos que este comience desde aquí, ¿verdad? Así que tomará 360 píxeles desde la izquierda y 180 píxeles desde la parte superior. Así que ahora, si probáramos nuestro código , verían que tenemos el resultado esperado. Ahora es un buen momento para cambiar nuestros marcos a negro porque hemos hecho un gran trabajo. Podemos seguir adelante y cambiarlos a negro. Ahora, lo que verán es solo una ventana que parece una ventana completamente negra, pero en el fondo, en el código real de Python, tenemos dos marcos que están divididos tal como queríamos. Así que ahora que he cambiado todos los fondos a negro, veremos lo mismo, pero en el fondo, en el código original, realmente tenemos dos marcos, quiero decir, tres marcos. Muy bien, espero que hayan pasado un buen rato desarrollando este proyecto hasta ese momento. En el próximo episodio, aprenderemos a crear más elementos en esa ventana para que podamos hacer clic en las cosas y así tener un juego básico. pasando y espero verte en el próximo episodio también, si disfrutaste ese no olvides hacer clic en el botón Me gusta y también hacer clic en el botón Suscribirse para que nunca te pierdas un video. Te veré muy pronto.

# %%
#Main(Principal)
from tkinter import *
import configuraciones
import utilidades

ventana = Tk()
# Configuración de la ventana
ventana.configure(bg="black")
ventana.geometry(f'{configuraciones.ANCHO}x{configuraciones.ALTO}')
ventana.title("Juego Buscaminas")
ventana.resizable(False, False)

marco_superior = Frame(
    ventana,
    bg='black',
    width=configuraciones.ANCHO,
    height=utilidades.altura_pct(25)
)
marco_superior.place(x=0, y=0)

marco_izquierdo = Frame(
    ventana,
    bg='black',
    width=utilidades.ancho_pct(25),
    height=utilidades.altura_pct(75)
)
marco_izquierdo.place(x=0, y=utilidades.altura_pct(25))

marco_central = Frame(
    ventana,
    bg='black',
    width=utilidades.ancho_pct(75),
    height=utilidades.altura_pct(75)
)
marco_central.place(
    x=utilidades.ancho_pct(25),
    y=utilidades.altura_pct(25),
)

# Ejecutar la ventana
ventana.mainloop()

# %%
#Settings(Configuraciones)
ANCHO = 1440
ALTO = 720

# %%
#Utils(Utilidades)
import configuraciones

def altura_pct(porcentaje):
    return (configuraciones.ALTO / 100) * porcentaje

def ancho_pct(porcentaje):
    return (configuraciones.ANCHO / 100) * porcentaje

# %% [markdown]
# ##TRANSCRIPCIÓN VIDEO LEARN TO BUILD A GAME (APRENDE A CONSTUIR UN JUEGO) Creating Cells & Mines (Creando celdas y minas)
#
#
#
# Este es el segundo episodio de la serie de desarrollo de juegos en Python. En este, comenzaremos a crear clases y métodos, y también implementaremos programación orientada a objetos para desarrollar un juego. Necesitamos crear celdas para simular el juego Mind Sweeper, lo que nos llevará a crear elementos dinámicamente. Tendremos que lidiar con mucha lógica para que nuestra ventana sea lo más dinámica posible. Hay mucho que esperar de este episodio. Como siempre, si disfrutas de este episodio, asegúrate de darle " me gusta" y suscribirte a mi canal para no perderte los próximos episodios. ¡Comencemos! [Música] Bien, hasta este punto, tenemos un marco aquí y también tenemos un marco aquí. Dijimos que aquí escribiríamos información sobre el juego. Aquí tendremos el título de Mind Sweeper , así. Pero lo que queremos hacer aquí en el centro es desarrollar el tablero, cada celda. que un jugador va a hacer clic debe estar aquí y aquí debemos ubicar todas nuestras celdas ahora creando 36 celdas o 49 celdas codificadas básicamente una gran cantidad de ventas va a ser difícil, así que aquí está la ubicación exacta en la que queremos hacer que nuestras cosas sean un poco más dinámicas queremos poder seguir adelante y hacer un bucle for que seguirá adelante y creará ese tipo de celdas dinámicamente ahora también queremos el comportamiento de cada celda el tipo
# de un comportamiento de botón llamado así porque queremos la capacidad de hacer clic en algo y luego, lo siguiente que sucederá algo en el juego, ¿verdad? Veremos información sobre esa celda, así que ese es el momento exacto para crear una clase que podemos nombrar vender porque sabemos que para cada celda también nos gusta dar algunos atributos como si la celda es mía o no o si esta es una celda que ya está abierta o está cerrada, así que ese es exactamente el momento en que es una gran idea pensar en crear una clase que podríamos llamar celda y podríamos crear algunas instancias de eso más adelante ahora, solo como un ejemplo rápido, voy a eliminar eso después, les mostraré el ejemplo básico, pero aquí se explica cómo pueden crear un botón en una ventana usando la biblioteca tkinter, ¿verdad? Entonces usemos una variable aleatoria como botón uno y eso será igual a botón así ahora este botón va a recibir varios argumentos digamos que queremos esto dentro de nuestro marco central y queremos darle el color de fondo azul y vamos a darle un texto perdón por faltar la coma aquí vamos a darle un texto como primero botón y luego lo que voy a hacer Ahora vamos a decir botón1 punto lugar lo colocaremos en el primer píxel en el eje x y el eje y en el marco central por lo que debe estar en la posición superior izquierda de ese marco central derecha así que si fuéramos a seguir adelante y ejecutar esto entonces puedes ver que tengo un botón ahí mismo y es cliqueable ahora sabemos que queremos abstraerlo con nuestra clase personalizada porque necesitamos dar a esa celda los llamados atributos como describí anteriormente por eso quiero crear una clase de celda y luego también veremos cómo la clase de botón va a estar involucrada dentro de esa clase de venta comenzaremos a desarrollar pero en realidad sigamos adelante y comencemos a trabajar en esto derecha así que solo quería mostrarte cómo crear un botón antes de seguir adelante y escribir más código así que iré aquí y crearé un archivo de celda de python derecha y haré zoom un poco para que todos puedan ver y usaré la clase celda ahora temporalmente no quiero heredar de la clase inferior derecha porque no es del todo correcto decir que una celda es un tipo de botón sabemos que usamos la herencia para describir tipos de cosas como perro es un un poco animal, por lo que la clase perro debería heredar de una clase que sea una clase animal, pero ese no es exactamente el caso aquí, así que no estoy haciendo eso y ahora que creé esta clase, sigamos adelante y escribamos el constructor de nuestra clase ahora, como sabemos, el constructor es un método que se llamará inmediatamente una vez que se instancia una clase ahora recibiré temporalmente aquí un parámetro al que también le voy a proporcionar un valor predeterminado de falso y puedes ver que se llama es mío, ¿ verdad? y voy a decir self punto es guión bajo el mío es igual a es guión bajo el mío como el siguiente derecho, así que ahora que tenemos esto, veamos cómo lo vamos a usar en nuestro código, así que iré a mi archivo main.py y nos desplazaremos justo encima de este comentario aquí, ejecutar la ventana y necesitaré importar la clase con seguridad, así que sigamos adelante y usemos desde la celda que es el archivo importar la clase de celda así, ¿verdad? y solo la voy a colocar en esa línea para que tengamos una apariencia más limpia ahora voy a ir aquí y solo voy a decir c1 es igual a la celda y luego lo dejaré como está porque tiene un valor predeterminado de falso y ahora que tengo esto, puedo seguir adelante y ejecutarlo y puedes ver que la nube, la instanciación es probablemente buena porque no recibimos flechas ahora, obviamente, no vemos ningún botón aquí porque acabamos de crear una clase personalizada sin relacionarla con la clase de botón que viene de esta biblioteca tkiinter, así que ahora esto es exactamente lo que vamos a hacer, ¿verdad? Vamos a nuestro archivo de celda y vamos a crear una instancia de botón que pertenecerá a cada objeto de celda, así que lo que eso significa es que este yo va a recibir un atributo más que podríamos nombrar objeto de botón de celda algo así y luego le vamos a asignar un objeto de botón y así es como se va a lograr la relación entre los objetos de celda y el objeto de botón, así que primero lo primero voy a cerrar el juego temporalmente y voy a ir aquí y decir desde tk inter import sabes qué, importemos solo la clase de botón no usemos una importación de comodín aquí y ahora voy a seguir adelante y decir que esto debería ser igual a Ninguno al principio y luego lo que vamos a hacer ahora es crear un método de instancia que creará este botón para nosotros y lo asignaré al objeto de botón self.cell. Veamos cómo lo haremos, así que diré crear un objeto de botón y recibiremos solo self por ahora y vamos a decir aquí que el botón es igual a un botón como ese y solo estamos instanciando una instancia de esa clase de botón. Actualmente no recibimos ningún parámetro adicional aparte del self, que es obligatorio en los métodos de instancia, por lo que necesitamos recibir al menos un parámetro que es bastante importante y que podemos llamar ubicación porque sabemos que para cada elemento que nos gustaría crear en nuestra ventana debemos pasar una pieza de información que hará que tk ingrese para comprender dónde debe ubicar ese elemento, así que si recibimos un parámetro llamado ubicación, entonces puedo pasar la ubicación directamente y luego, cada vez que llame a este método, me referiré al marco central real que será del punto principal py, por eso estoy recibiendo aquí el parámetro de ubicación. Correcto y solo para un ejemplo temporal, vamos a darle también un texto aleatorio como ese , como un principiante, y luego voy a decir que el objeto self dot cell btn va a ser igual al objeto del botón que acabo de crear y eso va a ser útil porque me ayudará a personalizar más adelante este botón una vez que asigne este atributo a un objeto de botón y verás en un minuto cómo eso va a ser extremadamente útil, así que sigamos adelante y dividamos ahora verticalmente para que podamos entender lo que hemos hecho aquí, así que en el lado izquierdo tenemos el archivo de celda y en el lado izquierdo voy a trabajar en mi archivo main.py, así que lo que voy a hacer ahora aquí es seguir adelante y decir c1 dot create button object porque puedo permitirme llamar a ese botón y luego tengo la capacidad de pasar la ubicación porque center frame es una variable a la que se puede acceder desde el archivo main.py, así que puedo decir directamente center frame como parámetro y luego puedo seguir trabajando con mi objeto de botón gracias a la asignación de atributos que he hecho aquí, así que puedo bajar y puedo Digamos c1 punto celda btn objeto punto lugar así y puedo decir que me gustaría colocarlo en x igual a cero e y igual a cero tal como lo hicimos al principio de este episodio y ahora que he hecho esto, entonces es un buen momento para probar nuestro código así que voy a ejecutar esta aplicación y verán que tenemos ese botón así que es un muy buen comienzo para desarrollar esta aplicación y distribuir el código en diferentes archivos para que sea más fácil de mantener y más legible bien ahora que hemos hecho esto, entonces necesitamos entender que vamos a tener algunos problemas en el futuro si seguimos usando ese método de lugar para colocar nuestros elementos ahora para mostrarles el problema del que estoy hablando voy a crear aquí una instancia más de la clase de celda que se nos ocurrió así que voy a decir que c2 es igual a celda como la siguiente y luego voy a decir c2.38 objeto de botón y va a ser el marco central nuevamente y luego quiero esta celda justo cerca de la primera celda correcta así que Debería decir algo como c2 punto celda botón objeto punto lugar y entonces deberíamos saber dinámicamente cuántos píxeles debemos saltar a la derecha para colocarlo exactamente en la ubicación que queremos, pero eso va a ser un gran dolor de cabeza y muchos problemas saber siempre la ubicación exacta que queremos pasar porque, por ejemplo, digamos que pasaré x igual a 20 e y igual a 0 y ejecutaré nuestro juego. Ahora puedes ver aquí que el botón derecho parece estar antes del botón izquierdo porque casi no podemos ver el texto en el botón izquierdo aquí, así que podemos intentar aumentar esta cantidad de x a 40 algo así y volver a ejecutar nuestro juego y puedes ver que ahora es mucho mejor, pero cuando queremos lidiar con la creación de múltiples elementos dinámicamente, entonces tal vez usar el modo de lugar no sea la mejor opción aquí, así que debemos considerar cambiar nuestro método de ubicación cuando usamos tk inter cuando se trata de decenas de elementos que queremos crear dinámicamente y podemos hacer esto cambiando nuestro método de lugar a cuadrícula. Ahora, ¿qué cuadrícula toma el elemento padre? Lo cual es bastante correcto. allí y gira el padre elemento en columnas y filas. Ahora, lo bueno es que cuenta desde cero las columnas y filas. Por ejemplo, si queremos colocar un botón justo ahí, podemos decir que queremos cuadricularlo y luego darle algunos valores que se considerarán como el número de columna y el número de fila. Veamos esto en acción. Puede que sea un poco confuso de entender en teoría, pero ahora que seguiremos adelante y codificaremos esto, será más fácil de entender. Voy a eliminar todo de aquí y volver a PyCharm y, de hecho, seguiré adelante y cambiaré el método de ubicación de cuadrícula en ambos botones. Voy a ir a mi C1 y voy a decir cuadrícula. Luego, pasaré aquí la columna igual a cero y la fila igual a cero. Así que ahora tomaré esos argumentos y los pasaré cambiando también este método a cuadrícula. Luego verá la diferencia cuando diga aquí la fila igual a uno. Y ahora, si siguiéramos adelante y ejecutáramos nuestro programa, entonces puede ver que tenemos una diferencia. Este texto aquí es usado estar en la columna cero fila cero pero este solía estar ubicado en la columna cero fila uno y esa es la razón por la que ves el segundo botón debajo del primer botón y si cambiara esto a cero y hiciera que uno significara columna igual a uno entonces verás esos botones uno cerca del otro lo cual es perfecto y será útil cuando queramos crear toneladas de botones para comenzar a prepararnos para el juego buscaminas bien ahora que entendimos cómo funciona el método de cuadrícula entonces vamos a comenzar a crear esas celdas como queremos en nuestro juego buscaminas ahora eso es algo que podemos lograr con un bucle for anidado así que déjame mostrarte cómo se verá para que sea más fácil de mantener en el futuro y eliminemos esto primero así que voy a comenzar mi primer bucle for y voy a decir para x en el rango de 5 por ejemplo ahora el rango es solo una función que es responsable de generar todos los enteros en el rango dado de números si solo aprobara el año 5 entonces generaría 0 1 2 3 y 4 así Bien, entonces voy a entrar aquí y luego voy a decir para ti en un rango de cinco, así que básicamente estoy logrando aquí el comportamiento de crear 25 botones porque tengo un bucle que itera cinco veces dentro de otro bucle que también itera cinco veces, así que ahora puedo ir dentro de eso y puedo decir que c es igual a celda, así que estoy instanciando un objeto de él y luego puedo seguir adelante y decir crear objeto btn y como la ubicación pasaré en el marco central con seguridad, así que ahora que hemos creado el objeto de botón, entonces puedo acceder a él con la propiedad que hemos creado previamente, que era el objeto btn de celda, y puedo usar la opción de cuadrícula y luego puedo pasar columna igual a y y puedo decir fila igual a x así y ahora veamos el resultado de eso, así que voy a ejecutarlo y puedes ver lo hermoso que se ve , así que ya estamos empezando a ver algo similar a un juego de buscaminas y eso es perfecto ahora lo que podemos hacer en lugar de codificar de forma rígida en los cinco en esos bucles for, podemos permitirnos ir al archivo de configuración y aquí mismo una nueva configuración que puede verse como el tamaño de la cuadrícula Entonces podemos decidir que es igual a cualquier número que queramos. Diré 6 solo porque este fue el número que mostré al principio de toda esta serie como un juego de ejemplo y luego iré aquí y diré "Configuración del tamaño de la cuadrícula de puntos" . Si recuerdas, importé todo el archivo de configuración allí mismo para poder acceder a la variable de tamaño de la cuadrícula y también puedo decir aquí lo mismo y luego puedo simplemente ejecutar nuestro programa nuevamente y puedes ver cómo se ve, así que tenemos seis columnas y filas así y eso es solo un gran comienzo ahora, antes de continuar y perdón por la confusión aquí, creo que será mejor si diremos que la columna es igual a x y rho es igual a y porque si, por ejemplo, cambiáramos esto a 3 y no la configuración.tamaño de la cuadrícula , entonces será más preciso decir que tenemos tres filas, ¿verdad? 1, 2 y 3. Así que es por eso que me quedaré con esos ajustes de columna igual y fila igual a y como se muestra a continuación y luego ahora puedo simplemente convertir esto de nuevo a configuración.tamaño crítico y continuar desde aquí. Bien, ahora que lo entendimos totalmente. Entonces probablemente también querremos entender cómo Podemos asignar eventos a nuestros botones. Un evento es básicamente una lista de acciones que se realizan al hacer clic en un botón. Al principio de esta serie dijimos que queríamos diferenciar entre la acción que se realiza al hacer clic izquierdo o derecho en un botón. Son dos acciones diferentes en un juego de buscaminas. Diseñar esto en el juego de buscaminas es genial . Dar eventos a los botones es una parte muy divertida del juego. Veamos cómo podemos hacerlo. Voy a ir a mi archivo cell.py y esta es la ubicación exacta donde podemos empezar a asignar eventos a los botones que creamos. Es exactamente la ubicación donde creamos nuestro objeto de botón. También podemos asignarle un evento. Escribamos esto: cuando queramos asignar un evento a un botón, trabajaremos con un método específico llamado bind. Con bind podemos imprimir algo cuando hagamos clic izquierdo en un botón. Veamos cómo. vamos a hacer Entonces, vamos a necesitar pasar dos argumentos. El primer argumento es la tecla que se hace clic en el botón y también cuál es la función que desea ejecutar una vez que haga clic en cualquier botón en el que haga clic. Primero, queremos decir que queremos hacer algo cuando hacemos clic izquierdo en un botón y la convención con el tk inter para pasar el clic izquierdo será algo como lo siguiente. Voy a usar el signo menor que y voy a decir botón, guión mayúscula 1, signo mayor que, así que botón, guión uno es solo una convención de decir clic izquierdo, botón, guión tres va a ser clic derecho y vamos a ver esto en un segundo y luego también nos gustaría decir que nos gustaría ejecutar alguna función, ¿verdad? Ese será el segundo argumento del método de enlace. Así que comencemos con la función más minimalista que se nos ocurra. Voy a crear un método dentro de mi clase de celda que llamaré acciones de clic izquierdo como esa y que también recibirá self, seguro que es un método de instancia y Entonces solo va a decir Estoy haciendo clic izquierdo solo como un ejemplo básico, lo dejaré como está y ahora que hemos hecho esto, entonces puedo pasar fácilmente la referencia para ese método, por lo que no será como las acciones de clic izquierdo y voy a llamar a este método así, además, solo le daré la referencia como la siguiente, así que preste atención a que no está llamando a este método, solo está pasando la referencia de ese método, así que ahora que tenemos esto, entonces veámoslo y veamos si eso va a funcionar para nosotros, así que voy a ir aquí y hacer esto un poco más grande y voy a intentar hacer clic en una de esas celdas aquí y puede ver que tenemos un error ahora puede ver que dice aquí las acciones de clic izquierdo toman un argumento posicional, pero se dieron dos ahora ese podría ser un error familiar que tal vez vio en mi serie oop, pero básicamente esto significa que estas acciones de autoclic intentan pasar dos argumentos cuando intentan llamar al método de acciones de clic izquierdo ahora eso significa que este método necesita recibir un parámetro adicional más para realizar esta asignación de evento con éxito y eso proviene de una convención de kinder, necesita recibir un parámetro más cuando asignas algo a un evento, puede ser un poco confuso, pero así es como funcionan los eventos en tk inter, así que por convención solo voy a recibir un parámetro inicial que voy a llamar evento. Ahora bien, esto debería ser suficiente porque tinter intenta pasar dos argumentos, así que pasar aquí otro parámetro debería ser perfecto. Así que voy a volver a ejecutar el programa y luego intentaré hacer clic en algunos botones. Puedes ver que tenemos un gran resultado aquí. Por cada botón en el que hago clic, recibo este texto cuando hago clic izquierdo y eso es perfecto. También me gustaría añadir aquí una línea más que será responsable de imprimir la información que llega a ese parámetro de evento . Verás que en realidad está lleno de información que tkinter pasa en segundo plano. Así que ahora volvamos a ejecutar nuestro juego. Si hiciera clic en algo, puedes ver que recibí información sobre cuál fue el evento que es precisa para que puedas ver que tengo un estado de evento de pulsación de botón igual a mod 1, básicamente algunos metadatos sobre el evento que se ha producido en ese momento y también puedes ver que recibo los valores de los ejes x e y para la ubicación exacta en la que se hizo clic, así que es solo una gran información de fondo que puedes seguir adelante y hacer algo con ella si quieres. Ahora puedes ver claramente por qué este método de enlace requiere que recibamos un parámetro más cuando asignamos una función como un evento que necesita ser llamado. Ahora podría ser una gran idea preparar también el método de enlace para nuestros clics derechos, así que voy a minimizar esta consola y solo voy a duplicar esta línea y voy a decir que también deberíamos vincular el botón guión 3, por lo que esto representará clic derecho y esto representará clic izquierdo. Ahora también puedes probar el botón guión 2 si el botón guión 3 no te funciona, solo por seguridad, si 3 no funciona cuando haces clic derecho, prueba también el botón guión 2. Si tienes más problemas, házmelo saber en la sección de comentarios. Bien, entonces estoy Voy a decir aquí acciones de clic derecho y obviamente voy a ir aquí y decir acciones de clic derecho para sordos y de nuevo voy a recibir este evento y voy a hacer lo mismo, así que primero voy a imprimir el evento y voy a decir que hago clic derecho para que podamos diferenciar entre los dos y voy a volver a ejecutar nuestro juego y sé que no puedes ver esto, pero voy a hacer clic derecho en eso y puedes ver que ahora tenemos el texto en la consola que es exactamente el mismo que la acción de clic derecho, así que eso es genial y pudimos asignar algunos eventos a todos nuestros botones dinámicamente, así que espero que lo hayan pasado bien en ese episodio. En el próximo episodio vamos a escribir la lógica sobre una mina en un juego de buscaminas. Habrá muchos métodos y lógica que tendremos que escribir para empezar a ver un juego real en marcha. Así que si disfrutaste en este episodio, dale me gusta y suscríbete a mi canal y nos vemos en el tercer episodio.
