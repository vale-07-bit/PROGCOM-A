# %% [markdown]
# <a href="https://colab.research.google.com/github/vale-07-bit/PROGCOM-A/blob/main/Florister%C3%ADa_04_NOV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Profe, no pude hacerlo en inteliggi entonces lo copie por acá

# %% [markdown]
# ```
# public class Casa {
#     // Propiedades de la clase (Atributos)
#     private String color;
#     private int numero_habitaciones;
#     private int numero_banos;
#     private boolean estacionamiento;
#     private boolean tiene_patio;
#
#     // Constructor
#     public Casa(String color, int numero_habitaciones, int numero_banos, boolean estacionamiento, boolean tiene_patio) {
#         this.color = color;
#         this.numero_habitaciones = numero_habitaciones;
#         this.numero_banos = numero_banos;
#         this.estacionamiento = estacionamiento;
#         this.tiene_patio = tiene_patio;
#     }
#
#     public String descripcion() {
#         String descripcion = "La casa es de color " + this.color + ", tiene " + this.numero_habitaciones + " habitaciones y " + this.numero_banos + " baños.";
#
#         if (this.estacionamiento) {
#             descripcion = descripcion + " Tiene estacionamiento.";
#         }
#         if (this.tiene_patio) {
#             descripcion = descripcion + " Tiene patio.";
#         }
#         return descripcion;
#     }
#
#     public void pintar(String nuevoColor) {
#         this.color = nuevoColor;
#         System.out.println("La casa fue pintada de: " + this.color);
#     }
#
#     // GETTERS Y SETTERS
#
#     public String getColor(){return this.color;}
#     public void setColor(String color){this.color = color;}
#
#     public int getNumero_habitaciones(){return this.numero_habitaciones;}
#     public void setNumero_habitaciones(int numero_habitaciones){
#         this.numero_habitaciones = numero_habitaciones;
#     }
#
#     public int getNumero_banos(){return this.numero_banos;}
#     public void setNumero_banos(int numero_banos){this.numero_banos = numero_banos;}
#
#     public boolean getEstacionamiento(){return this.estacionamiento;}
#     public void setEstacionamiento(boolean estacionamiento){this.estacionamiento = estacionamiento;}
#
#     public boolean getTiene_patio(){return this.tiene_patio;}
#     public void setTiene_patio(boolean tiene_patio){this.tiene_patio = tiene_patio;}
#
# public class Main{
#   public static void main(String[] args) {
#     Casa casaValery = new Casa ("Blanco", 5, 2, )
#     System.out.print(casaValery);
#     casaValery.pintar("Azul Navy");
#     System.out.printLln(casaValery.desccripción())
# }
# ```
# Tarea: Falta la segunda parte que es cuando creamos la floristería.
